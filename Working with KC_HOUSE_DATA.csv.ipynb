# %% [markdown]
# SET THE DIRECTORY

# %%
# %cd D:\DATA ANALYSIS USING PYTHON\INTRODUCTION TO PYTHON\Python+Course+Assignments\BASICS USING kc_house DATA
# Out:
# D:\DATA ANALYSIS USING PYTHON\INTRODUCTION TO PYTHON\Python+Course+Assignments\BASICS USING kc_house DATA

# %% [markdown]
# LOAD THE PACKAGES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# READ THE DATA

# %%
data = pd.read_csv("kc_house_data.csv")

# %% [markdown]
# PERFORM BASIC DATA EXPLORATION FUNCTIONS

# %%
# print first five rows from the data frame (data)
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3          1         1180
# 1  6414100192  20141209T000000  538000.0         3          2         2570
# 2  5631500400  20150225T000000  180000.0         2          1          770
# 3  2487200875  20141209T000000  604000.0         4          3         1960
# 4  1954400510  20150218T000000  510000.0         3          2         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
# print last five rows from the data frame (data)
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3          3
# 21609  6600060120  20150223T000000  400000.0         4          3
# 21610  1523300141  20140623T000000  402101.0         2          1
# 21611   291310100  20150116T000000  400000.0         3          3
# 21612  1523300157  20141015T000000  325000.0         2          1
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0              0      2009             0    98103  47.6993
# ...

# %%
# Applying the condition
data["yr_renovated"] = np.where(data["yr_renovated"] == 0, 0, 1)

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.312543   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.865405    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      2.000000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.000000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      3.000000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# to see the column names from the dataframe
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms          int64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.info () # to get more information about the data (specfically with respect to the data structure)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  int64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  category
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.shape # to understand the number of rows and columns in the data
# Out:
# (21613, 21)

# %%
# covert date variable from object format to 'date' format
data['date'] = pd.to_datetime(data['date'], format = "%Y%m%dT000000")
data.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms                 int64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above              float64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# DATA SLICING

# %%
#selecting specfic columns from the data frame based on "column name"
data1 = data[['price','bedrooms', 'bathrooms', 'sqft_living']]
data1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living
# 0  221900.0         3          1         1180
# 1  538000.0         3          2         2570
# 2  180000.0         2          1          770
# 3  604000.0         4          3         1960
# 4  510000.0         3          2         1680

# %% [markdown]
# CLASS ACTIVITY_1

# %%
# Create a data frame with only the following variables
 #'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'

# %%
# Create a data frame with only the following variables
# 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode'

# %%
# Create a data frame with only the following variables 'floors', 'waterfront', 'view', 'condition', 'grade'

# %%
# Create a data frame with only the following variables
#'id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view'

# %% [markdown]
# Use of iloc

# %%
# using iloc function to locate the rows or columns based on integer based location (iloc)
data2 =  data.iloc[0:4,[1,2,5,6]]
data2
# Out:
#         date     price  sqft_living  sqft_lot
# 0 2014-10-13  221900.0         1180      5650
# 1 2014-12-09  538000.0         2570      7242
# 2 2015-02-25  180000.0          770     10000
# 3 2014-12-09  604000.0         1960      5000

# %%
# using iloc function to locate the rows or columns based on integer based location (iloc)
data3 =  data.iloc[0:4,:5]
data3
# Out:
#            id       date     price  bedrooms  bathrooms
# 0  7129300520 2014-10-13  221900.0         3          1
# 1  6414100192 2014-12-09  538000.0         3          2
# 2  5631500400 2015-02-25  180000.0         2          1
# 3  2487200875 2014-12-09  604000.0         4          3

# %% [markdown]
# ACTIVITY_2

# %%
# select first five rows and five columns

# %%
# select rows 100 to 200 and columns 1 to 9

# %%
# select all rows and last five columns

# %%
# select first 100 rows and all columns

# %%
# select last 100 rows and first five columns

# %% [markdown]
# Slicng the data based on 'loc' function

# %%
data3 = data.loc[data['date'] >= "2014-10-01"]
data3
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3          1         1180
# 1      6414100192 2014-12-09   538000.0         3          2         2570
# 2      5631500400 2015-02-25   180000.0         2          1          770
# 3      2487200875 2014-12-09   604000.0         4          3         1960
# 4      1954400510 2015-02-18   510000.0         3          2         1680
# ...           ...        ...        ...       ...        ...          ...
# 21606  7936000429 2015-03-26  1010000.0         4          4         3510
# 21607  2997800021 2015-02-19   475000.0         3          3         1310
# 21609  6600060120 2015-02-23   400000.0         4          3         2310
# 21611   291310100 2015-01-16   400000.0         3          3         1600
# 21612  1523300157 2014-10-15   325000.0         2          1         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data4 = data.loc[(data['date'] >= "2014-10-01") & (data['date'] <= "2014-12-01")]
data4
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3          1         1180
# 13     6054650070 2014-10-07   400000.0         3          2         1370
# 24     3814700200 2014-11-20   329000.0         3          2         2450
# 25     1202000200 2014-11-03   233000.0         3          2         1710
# 27     3303700376 2014-12-01   667000.0         3          1         1400
# ...           ...        ...        ...       ...        ...          ...
# 21595  1972201967 2014-10-31   520000.0         2          2         1530
# 21598  8956200760 2014-10-13   541800.0         4          3         3118
# 21600   249000205 2014-10-15  1540000.0         5          4         4470
# 21605  3448900210 2014-10-14   610685.0         4          3         2520
# 21612  1523300157 2014-10-15   325000.0         2          1         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data5 = data.loc[(data["waterfront"] == 1) & (data["grade"] > 7)]
data5
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 49      822039084 2015-03-11  1350000.0         3          3         2753
# 246    2025069065 2014-09-29  2400000.0         4          3         3650
# 300    3225069065 2014-06-24  3080000.0         4          5         4550
# 457    2122039094 2014-11-26   705000.0         3          3         1970
# 540     622049114 2015-02-18  2130000.0         3          3         5403
# ...           ...        ...        ...       ...        ...          ...
# 19984  2025069140 2015-03-17  1900000.0         3          3         2830
# 20325   518500480 2014-08-11  3000000.0         3          4         4410
# 20767  8043700105 2015-04-17  2300000.0         4          4         4360
# 21201   518500460 2014-10-08  2230000.0         3          4         3760
# 21576  9253900271 2015-01-07  3570000.0         5          5         4850
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ACTIVITY_3

# %%
#select houses with grade >8 and build after 2000

# %%
# select houses with no waterfront and grade <8

# %%
# select houses with sqrt living less than 3000 with grade > 8

# %%
# select those hoses with sqrt living less than 3000, and grade > 8 and constructed after 2000

# %%
# select those houses which got grade between 8-10 and constructed after 2000

# %% [markdown]
# DROP COLUMNS

# %%
data = data.drop(columns = ["id", "price"])
data.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3          1         1180      5650     1.0
# 1  20141209T000000         3          2         2570      7242     2.0
# 2  20150225T000000         2          1          770     10000     1.0
# 3  20141209T000000         4          3         1960      5000     1.0
# 4  20150218T000000         3          2         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7      1180.0              0      1955
# 1           0     0          3      7      2170.0            400      1951
# 2           0     0          3      6       770.0              0      1933
# 3           0     0          5      7      1050.0            910      1965
# 4           0     0          3      8      1680.0              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ACTIVITY_4

# %%
# drop the mentioned columns 'sqft_living', 'sqft_lot', 'view', 'condition'

# %% [markdown]
# CREATING CATGORICAL VARIABLES

# %%
data['waterfront'] = data["waterfront"].astype("category")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3          1         1180
# 1  6414100192  20141209T000000  538000.0         3          2         2570
# 2  5631500400  20150225T000000  180000.0         2          1          770
# 3  2487200875  20141209T000000  604000.0         4          3         1960
# 4  1954400510  20150218T000000  510000.0         3          2         1680
#
#    sqft_lot  floors waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0          0     0  ...      7      1180.0              0
# 1      7242     2.0          0     0  ...      7      2170.0            400
# 2     10000     1.0          0     0  ...      6       770.0              0
# 3      5000     1.0          0     0  ...      7      1050.0            910
# 4      8080     1.0          0     0  ...      8      1680.0              0
#
# ...

# %% [markdown]
# CREATE DATA SUMMARY

# %%
data.describe(include = "category")
# Out:
#         waterfront
# count        21613
# unique           2
# top              0
# freq         21450

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.312543   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.865405    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      2.000000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.000000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      3.000000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors          view     condition         grade  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# SORTING THE DATA

# %%
# sorting based on single column(price)
data = data.sort_values("price", ascending = False)
data.head()
# Out:
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020 2014-10-13  7700000.0         6          8        12050
# 3914  9808700762 2014-06-11  7060000.0         5          5        10040
# 9254  9208900037 2014-09-19  6890000.0         6          8         9890
# 4411  2470100110 2014-08-04  5570000.0         5          6         9200
# 1448  8907500070 2015-04-13  5350000.0         5          5         8000
#
#       sqft_lot  floors waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5          0     3  ...     13      8570.0
# 3914     37325     2.0          1     2  ...     11      7680.0
# 9254     31374     2.0          0     4  ...     13      8860.0
# 4411     35069     2.0          0     0  ...     13      6200.0
# 1448     23985     2.0          0     4  ...     12      6720.0
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#sorting the data based on multiple columns (price and yr_built)

data = data.sort_values(["price", "yr_built"], ascending = False)
data.head()
# Out:
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020 2014-10-13  7700000.0         6          8        12050
# 3914  9808700762 2014-06-11  7060000.0         5          5        10040
# 9254  9208900037 2014-09-19  6890000.0         6          8         9890
# 4411  2470100110 2014-08-04  5570000.0         5          6         9200
# 1448  8907500070 2015-04-13  5350000.0         5          5         8000
#
#       sqft_lot  floors waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5          0     3  ...     13      8570.0
# 3914     37325     2.0          1     2  ...     11      7680.0
# 9254     31374     2.0          0     4  ...     13      8860.0
# 4411     35069     2.0          0     0  ...     13      6200.0
# 1448     23985     2.0          0     4  ...     12      6720.0
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#sorting the data based on multiple columns (price and yr_built), where price in ascending and yr_built decending

data = data.sort_values(["price", "yr_built"], ascending = [1,0])
data.head()
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032 2015-02-17  75000.0         1          0          670
# 15293    40000362 2014-05-06  78000.0         2          1          780
# 465    8658300340 2014-05-23  80000.0         1          1          430
# 16198  3028200080 2015-03-24  81000.0         2          1          730
# 8274   3883800011 2014-11-05  82000.0         3          1          860
#
#        sqft_lot  floors waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0          0     0  ...      3       670.0
# 15293     16344     1.0          0     0  ...      5       780.0
# 465        5050     1.0          0     0  ...      4       430.0
# 16198      9975     1.0          0     0  ...      5       730.0
# 8274      10426     1.0          0     0  ...      6       860.0
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ACTIVITY_5

# %%
#sort the data (decending) based on price

# %%
# sort the data (ascending) based on price and yr_built (decending)

# %%
# sort the data based on date (decending) and price (ascending)

# %% [markdown]
# CREATING NEW COLUMNS: MAKING CHANGES IN THE DATA

# %%
# picking up only the year from the 'date' column and create a new column, "year"
data['year'] = data['date'].dt.to_period('Y')

data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3          1         1180
# 1  6414100192 2014-12-09  538000.0         3          2         2570
# 2  5631500400 2015-02-25  180000.0         2          1          770
# 3  2487200875 2014-12-09  604000.0         4          3         1960
# 4  1954400510 2015-02-18  510000.0         3          2         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# MISSING VALUES

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# year             0
# age              0
# dtype: int64

# %%
data[data['sqft_above'].isnull()]
# Out:
#             id       date     price  bedrooms  bathrooms  sqft_living  \
# 10  1736800520 2015-04-03  662500.0         3          3         3560
# 17  6865200140 2014-05-29  485000.0         4          1         1600
#
#     sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 10      9796     1.0           0     0  ...           1700      1965
# 17      4300     1.5           0     0  ...              0      1916
#
#     yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# 10             0    98007  47.6007 -122.145           2210        8925    45
# 17             0    98103  47.6648 -122.343           1610        4300    44
#
#      age
# 10  0050
# 17  0098
#
# [2 rows x 23 columns]

# %% [markdown]
# DELETE THE ROWS WITH MISSING OBSERVATIONS

# %%
data.shape
# Out:
# (21613, 23)

# %%
data = data.dropna()
data.shape
# Out:
# (21611, 21)

# %% [markdown]
# CHANGING THE COLUMN NAMES INTO A DIFFERENT ONE

# %%
data1 = data.rename({'price': 'X', 'yr_built': 'Y'}, axis=1) 
data1.head()
# Out:
#            id             date         X  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3          1         1180
# 1  6414100192  20141209T000000  538000.0         3          2         2570
# 2  5631500400  20150225T000000  180000.0         2          1          770
# 3  2487200875  20141209T000000  604000.0         4          3         1960
# 4  1954400510  20150218T000000  510000.0         3          2         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
ACTIVITY_6

# %%
# change X as price and Y as yr_built

# %%
# change sqft_living as area_living and sqft_basement as base_area

# %% [markdown]
# Summarize / Aggregate/group over entire column(s)

# %%
# summary based on some specfic parameters
data.agg(['mean', 'min'])
# Out:
#                 id             date          price  bedrooms  bathrooms  \
# mean  4.580302e+09              NaN  540182.158793  3.370842   2.312543
# min   1.000102e+06  20140502T000000   75000.000000  0.000000   0.000000
#
#       sqft_living      sqft_lot    floors  waterfront      view  ...  \
# mean  2079.899736  15106.967566  1.494309    0.007542  0.234303  ...
# min    290.000000    520.000000  1.000000    0.000000  0.000000  ...
#
#          grade   sqft_above  sqft_basement     yr_built  yr_renovated  \
# mean  7.656873  1788.396095     291.509045  1971.005136      0.042289
# min   1.000000   290.000000       0.000000  1900.000000      0.000000
#
#            zipcode        lat        long  sqft_living15    sqft_lot15
# mean  98077.939805  47.560053 -122.213896    1986.552492  12768.455652
# min   98001.000000  47.155900 -122.519000     399.000000    651.000000
#
# [2 rows x 21 columns]

# %%
# CREATE GROUPED SUMMARY

# %%
data['waterfront'] = data['waterfront'].astype("category")
mysummary = data.groupby(['waterfront']).agg(['mean', 'min'])
mysummary
# Out:
#                       id                    price            bedrooms      \
#                     mean        min          mean       min      mean min
# waterfront
# 0           4.580984e+09    1000102  5.316534e+05   75000.0  3.371375   0
# 1           4.490512e+09  121029034  1.662524e+06  285000.0  3.300613   1
#
#            bathrooms      sqft_living       ...       zipcode         \
#                 mean min         mean  min  ...          mean    min
# waterfront                                  ...
# 0           2.308438   0  2071.587972  290  ...  98077.798555  98001
# 1           2.852761   1  3173.687117  440  ...  98096.527607  98004
#
#                   lat                 long          sqft_living15       \
#                  mean      min        mean      min          mean  min
# waterfront
# 0           47.560225  47.1559 -122.213382 -122.519   1981.386667  399
# 1           47.537364  47.3276 -122.281601 -122.514   2666.349693  750
#
#               sqft_lot15
# ...

# %% [markdown]
# Concatenate / Bind Rows and Columns

# %%
data1 = data.iloc[:,0:10]# split the data (where first 10 columns retailed )
data1
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3          1
# 1      6414100192  20141209T000000  538000.0         3          2
# 2      5631500400  20150225T000000  180000.0         2          1
# 3      2487200875  20141209T000000  604000.0         4          3
# 4      1954400510  20150218T000000  510000.0         3          2
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3          3
# 21609  6600060120  20150223T000000  400000.0         4          3
# 21610  1523300141  20140623T000000  402101.0         2          1
# 21611   291310100  20150116T000000  400000.0         3          3
# 21612  1523300157  20141015T000000  325000.0         2          1
#
#        sqft_living  sqft_lot  floors waterfront  view
# 0             1180      5650     1.0          0     0
# 1             2570      7242     2.0          0     0
# ...

# %%
data2 = data.iloc[:,10:] # split the data (from 11th column onwards) and created second dataframe (data2)
data2
# Out:
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0              3      7      1180.0              0      1955             0
# 1              3      7      2170.0            400      1951             1
# 2              3      6       770.0              0      1933             0
# 3              5      7      1050.0            910      1965             0
# 4              3      8      1680.0              0      1987             0
# ...          ...    ...         ...            ...       ...           ...
# 21608          3      8      1530.0              0      2009             0
# 21609          3      8      2310.0              0      2014             0
# 21610          3      7      1020.0              0      2009             0
# 21611          3      8      1600.0              0      2004             0
# 21612          3      7      1020.0              0      2008             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
#merge the data
data3 = pd.concat([data1, data2], axis=1)
data3
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3          1
# 1      6414100192  20141209T000000  538000.0         3          2
# 2      5631500400  20150225T000000  180000.0         2          1
# 3      2487200875  20141209T000000  604000.0         4          3
# 4      1954400510  20150218T000000  510000.0         3          2
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3          3
# 21609  6600060120  20150223T000000  400000.0         4          3
# 21610  1523300141  20140623T000000  402101.0         2          1
# 21611   291310100  20150116T000000  400000.0         3          3
# 21612  1523300157  20141015T000000  325000.0         2          1
#
#        sqft_living  sqft_lot  floors waterfront  view  ...  grade  sqft_above  \
# 0             1180      5650     1.0          0     0  ...      7      1180.0
# ...

# %%
data['waterfront'] = data['waterfront'].dtype("Float64")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-368-61442a381df1> in <module>
# ----> 1 data['waterfront'] = data['waterfront'].dtype("Float64")
#
# TypeError: 'numpy.dtype[object_]' object is not callable

# %%
data['waterfront'] = data['waterfront'].astype ("category")

# %%
# to check whetehr there exists any na values in price column
data['price'].hasnans
# Out:
# False

# %%
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  int64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# converting a flot (numeric) vector to int format
data['price'] = data['price'].astype ('int')
data
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3          1         1180
# 1      6414100192  20141209T000000  538000         3          2         2570
# 2      5631500400  20150225T000000  180000         2          1          770
# 3      2487200875  20141209T000000  604000         4          3         1960
# 4      1954400510  20150218T000000  510000         3          2         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3          3         1530
# 21609  6600060120  20150223T000000  400000         4          3         2310
# 21610  1523300141  20140623T000000  402101         2          1         1020
# 21611   291310100  20150116T000000  400000         3          3         1600
# 21612  1523300157  20141015T000000  325000         2          1         1020
#
# ...

# %%
# converting the above created integer into flot
data['price'] = data['price'].astype ('int').astype('float')
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3          1
# 1      6414100192  20141209T000000  538000.0         3          2
# 2      5631500400  20150225T000000  180000.0         2          1
# 3      2487200875  20141209T000000  604000.0         4          3
# 4      1954400510  20150218T000000  510000.0         3          2
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3          3
# 21609  6600060120  20150223T000000  400000.0         4          3
# 21610  1523300141  20140623T000000  402101.0         2          1
# 21611   291310100  20150116T000000  400000.0         3          3
# 21612  1523300157  20141015T000000  325000.0         2          1
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3          1         1180
# 1  6414100192  20141209T000000  538000.0         3          2         2570
# 2  5631500400  20150225T000000  180000.0         2          1          770
# 3  2487200875  20141209T000000  604000.0         4          3         1960
# 4  1954400510  20150218T000000  510000.0         3          2         1680
#
#    sqft_lot  floors waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0          0     0  ...      7      1180.0              0
# 1      7242     2.0          0     0  ...      7      2170.0            400
# 2     10000     1.0          0     0  ...      6       770.0              0
# 3      5000     1.0          0     0  ...      7      1050.0            910
# 4      8080     1.0          0     0  ...      8      1680.0              0
#
# ...

# %%
data = data.loc[data['waterfront'] == "0"] = "1"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-416-0581885efeff> in <module>
# ----> 1 data = data.loc[data['waterfront'] == "0"] = "1"
#
# AttributeError: 'str' object has no attribute 'loc'

# %% [markdown]
# BEST MATERIAL FOR COMPARISION BETWEEN (R: DPLYR AND PYTHON: PANDAS)
# https://towardsdatascience.com/python-pandas-vs-r-dplyr-5b5081945ccb
